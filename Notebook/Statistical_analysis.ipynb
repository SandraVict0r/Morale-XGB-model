# %% [markdown]
# # Library

# %%
from library import *

# %% [markdown]
# # Dataset organization

# %%
data = pd.read_csv("data.csv", sep=";")
data
# Out:
#       left_char  right_char  strength_left  strength_right  value_left  \
# 0             2           6              7               3           8
# 1             6           5              3               6           1
# 2             6           3              3               8           1
# 3             7           6             10               3           0
# 4             3           5              8               6           5
# ...         ...         ...            ...             ...         ...
# 8959          6           1             11               1           5
# 8960          5           2             14              11           7
# 8961          6           1             11               1           6
# 8962          1           4              1              11           5
# 8963          5           7             14              10           5
#
#       scenario  value_left_rep1  value_left_rep2  sex  age
# 0            4               -1               -1    0   57
# 1            2               -1               -1    0   57
# 2            3               -1               -1    0   57
# 3            9               -1               -1    0   57
# 4            7               -1               -1    0   57
# ...        ...              ...              ...  ...  ...
# 8959         8                7                8    1   21
# 8960         5                6                7    1   21
# 8961         2                9                5    1   21
# 8962         7                3                2    1   21
# 8963         4                3                5    1   21
#
# [8964 rows x 10 columns]

# %%
#we print label in left and right char to be more readable
for s in ["left","right"]:
    data[ s + "_char"] = [ 'p1' if i == 1 
                               else 'p2' if i == 2 
                                else 'p3' if i == 3 
                                else 'p4' if i == 4 
                                else 'p5' if i == 5 
                                else 'p6' if i == 6 
                                else 'p7' if i == 7 
                                else i for i in data[s + "_char"]]
data
# Out:
#      left_char right_char  strength_left  strength_right  value_left  \
# 0           p2         p6              7               3           8
# 1           p6         p5              3               6           1
# 2           p6         p3              3               8           1
# 3           p7         p6             10               3           0
# 4           p3         p5              8               6           5
# ...        ...        ...            ...             ...         ...
# 8959        p6         p1             11               1           5
# 8960        p5         p2             14              11           7
# 8961        p6         p1             11               1           6
# 8962        p1         p4              1              11           5
# 8963        p5         p7             14              10           5
#
#       scenario  value_left_rep1  value_left_rep2  sex  age
# 0            4               -1               -1    0   57
# 1            2               -1               -1    0   57
# 2            3               -1               -1    0   57
# 3            9               -1               -1    0   57
# 4            7               -1               -1    0   57
# ...        ...              ...              ...  ...  ...
# 8959         8                7                8    1   21
# 8960         5                6                7    1   21
# 8961         2                9                5    1   21
# 8962         7                3                2    1   21
# 8963         4                3                5    1   21
#
# [8964 rows x 10 columns]

# %%
#we separate the dataset by scenario type
data_d = data[data.scenario < 4]
data_f = data[(data.scenario > 3) & (data.scenario < 7)]
data_r = data[data.scenario > 6]

display(data_d)
display(data_f)
display(data_r)
# Out:
#      left_char right_char  strength_left  strength_right  value_left  \
# 1           p6         p5              3               6           1
# 2           p6         p3              3               8           1
# 6           p1         p6              1               3           5
# 11          p6         p5              3               6           1
# 14          p1         p6              1               3           5
# ...        ...        ...            ...             ...         ...
# 8953        p7         p2             10              11           8
# 8954        p6         p1             11               1           5
# 8955        p7         p2             10              11           8
# 8956        p5         p1             14               1           8
# 8961        p6         p1             11               1           6
#
#       scenario  value_left_rep1  value_left_rep2  sex  age
# 1            2               -1               -1    0   57
# 2            3               -1               -1    0   57
# 6            1               -1               -1    0   57
# 11           2                1               -1    0   57
# 14           1                5               -1    0   57
# ...        ...              ...              ...  ...  ...
# 8953         3                8               -1    1   21
# 8954         2                9               -1    1   21
# 8955         3                8                8    1   21
# 8956         1                7                9    1   21
# 8961         2                9                5    1   21
#
# [2988 rows x 10 columns]
#      left_char right_char  strength_left  strength_right  value_left  \
# 0           p2         p6              7               3           8
# 7           p1         p6              1               3           2
# 8           p4         p3              5               8           2
# 9           p1         p6              1               3           2
# 15          p2         p6              7               3           5
# ...        ...        ...            ...             ...         ...
# 8951        p5         p2             14              11           7
# 8952        p3         p6             11              11           6
# 8957        p3         p6             11              11           6
# 8960        p5         p2             14              11           7
# 8963        p5         p7             14              10           5
#
#       scenario  value_left_rep1  value_left_rep2  sex  age
# 0            4               -1               -1    0   57
# 7            5               -1               -1    0   57
# 8            6               -1               -1    0   57
# 9            5                2               -1    0   57
# 15           4                8               -1    0   57
# ...        ...              ...              ...  ...  ...
# 8951         5                6               -1    1   21
# 8952         6                7               -1    1   21
# 8957         6                7                6    1   21
# 8960         5                6                7    1   21
# 8963         4                3                5    1   21
#
# [2988 rows x 10 columns]
#      left_char right_char  strength_left  strength_right  value_left  \
# 3           p7         p6             10               3           0
# 4           p3         p5              8               6           5
# 5           p7         p1             10               1           0
# 10          p7         p6             10               3           0
# 12          p3         p5              8               6           5
# ...        ...        ...            ...             ...         ...
# 8949        p6         p1             11               1           8
# 8950        p1         p4              1              11           2
# 8958        p1         p2              1              11           3
# 8959        p6         p1             11               1           5
# 8962        p1         p4              1              11           5
#
#       scenario  value_left_rep1  value_left_rep2  sex  age
# 3            9               -1               -1    0   57
# 4            7               -1               -1    0   57
# 5            8               -1               -1    0   57
# 10           9                0               -1    0   57
# 12           7                5               -1    0   57
# ...        ...              ...              ...  ...  ...
# 8949         8                7               -1    1   21
# 8950         7                3               -1    1   21
# 8958         9                5                5    1   21
# 8959         8                7                8    1   21
# 8962         7                3                2    1   21
#
# [2988 rows x 10 columns]

# %% [markdown]
# # ANOVA

# %%
#We calculate the anova on the value give for each type of character
lm_d = ols('value_left ~ C(left_char)', data=data_d).fit()
anova_d = sm.stats.anova_lm(lm_d, typ=1)

lm_f = ols('value_left ~ C(left_char)', data=data_f).fit()
anova_f = sm.stats.anova_lm(lm_f, typ=1)

lm_r = ols('value_left ~ C(left_char)', data=data_r).fit()
anova_r = sm.stats.anova_lm(lm_r, typ=1)

#We display it in a table in Markdown
display(Markdown("## ANOVA in DANGER"))
display(anova_d)
display(Markdown("## ANOVA in FATIGUE"))
display(anova_f)
display(Markdown("## ANOVA in REWARD"))
display(anova_r)
# Out:
# ## ANOVA in DANGER
#                   df        sum_sq      mean_sq           F         PR(>F)
# C(left_char)     6.0   8068.363916  1344.727319  243.602381  6.505221e-254
# Residual      2981.0  16455.636084     5.520173         NaN            NaN
# ## ANOVA in FATIGUE
#                   df        sum_sq      mean_sq           F  PR(>F)
# C(left_char)     6.0  12037.568309  2006.261385  369.531986     0.0
# Residual      2981.0  16184.431691     5.429195         NaN     NaN
# ## ANOVA in REWARD
#                   df        sum_sq      mean_sq           F         PR(>F)
# C(left_char)     6.0   6132.559531  1022.093255  203.593072  4.613125e-218
# Residual      2981.0  14965.440469     5.020275         NaN            NaN

# %% [markdown]
# # Post-hoc : Bonferroni correction

# %%
display(Markdown('# POST HOC IN DANGER'))
p_value_d = sp.posthoc_ttest(data_d,
                           val_col='value_left',
                           group_col='left_char') * 6

display(p_value_d)

display(Markdown('# POST HOC IN FATIGUE'))
p_value_f = sp.posthoc_ttest(data_f,
                           val_col='value_left',
                           group_col='left_char') * 6

display(p_value_f)

display(Markdown('# POST HOC IN REWARD'))
p_value_r = sp.posthoc_ttest(data_r,
                           val_col='value_left',
                           group_col='left_char') * 6

display(p_value_r)
# Out:
# # POST HOC IN DANGER
#                p6             p1             p7            p2            p4  \
# p6   6.000000e+00   2.220688e-06  7.668165e-138  4.259280e-24  1.846774e-13
# p1   2.220688e-06   6.000000e+00  2.913224e-183  5.105871e-50  1.103327e-34
# p7  7.668165e-138  2.913224e-183   6.000000e+00  1.677490e-56  1.687516e-73
# p2   4.259280e-24   5.105871e-50   1.677490e-56  6.000000e+00  4.220088e-02
# p4   1.846774e-13   1.103327e-34   1.687516e-73  4.220088e-02  6.000000e+00
# p3   1.017064e-46   6.103503e-80   2.652985e-37  4.302161e-04  1.241389e-10
# p5   5.684580e-36   2.189219e-67   1.233634e-48  2.456533e-01  8.062039e-06
#
#               p3            p5
# p6  1.017064e-46  5.684580e-36
# p1  6.103503e-80  2.189219e-67
# p7  2.652985e-37  1.233634e-48
# p2  4.302161e-04  2.456533e-01
# p4  1.241389e-10  8.062039e-06
# p3  6.000000e+00  2.544102e-01
# p5  2.544102e-01  6.000000e+00
# # POST HOC IN FATIGUE
#               p2             p1            p4             p7             p6  \
# p2  6.000000e+00   4.211564e-93  4.872187e-05   8.846925e-59   2.900505e-50
# p1  4.211564e-93   6.000000e+00  1.189534e-65  3.619884e-276   2.490139e-15
# p4  4.872187e-05   1.189534e-65  6.000000e+00   3.056244e-96   3.694713e-27
# p7  8.846925e-59  3.619884e-276  3.056244e-96   6.000000e+00  7.960807e-213
# p6  2.900505e-50   2.490139e-15  3.694713e-27  7.960807e-213   6.000000e+00
# p3  1.237538e-01  1.466126e-101  3.058227e-10   2.454072e-38   2.574936e-60
# p5  3.683868e+00  6.138183e-101  1.133044e-04   3.197449e-70   1.039348e-53
#
#                p3             p5
# p2   1.237538e-01   3.683868e+00
# p1  1.466126e-101  6.138183e-101
# p4   3.058227e-10   1.133044e-04
# p7   2.454072e-38   3.197449e-70
# p6   2.574936e-60   1.039348e-53
# p3   6.000000e+00   1.762628e-02
# p5   1.762628e-02   6.000000e+00
# # POST HOC IN REWARD
#                p7             p3            p4             p2            p1  \
# p7   6.000000e+00  1.844268e-110  8.719958e-94  2.064315e-104  3.756928e-40
# p3  1.844268e-110   6.000000e+00  5.709729e-04   3.558033e-01  5.894934e-27
# p4   8.719958e-94   5.709729e-04  6.000000e+00   2.971476e-01  1.848423e-14
# p2  2.064315e-104   3.558033e-01  2.971476e-01   6.000000e+00  2.090274e-20
# p1   3.756928e-40   5.894934e-27  1.848423e-14   2.090274e-20  6.000000e+00
# p6   1.632715e-79   6.142930e-07  5.845152e-01   2.774881e-03  4.031316e-09
# p5  7.048285e-105   1.820117e-03  3.460509e+00   7.469386e-01  1.057016e-17
#
#               p6             p5
# p7  1.632715e-79  7.048285e-105
# p3  6.142930e-07   1.820117e-03
# p4  5.845152e-01   3.460509e+00
# p2  2.774881e-03   7.469386e-01
# p1  4.031316e-09   1.057016e-17
# p6  6.000000e+00   1.334076e-01
# p5  1.334076e-01   6.000000e+00

# %% [markdown]
# # Detailed analysis of participants' responses

# %%
#we take id from participant
data_id = pd.read_csv('data_id.csv', sep=";")
data_id
# Out:
#                         id_participant
# 0     d60c0832fc30e645ca04f074c44b49eb
# 1     d60c0832fc30e645ca04f074c44b49eb
# 2     d60c0832fc30e645ca04f074c44b49eb
# 3     d60c0832fc30e645ca04f074c44b49eb
# 4     d60c0832fc30e645ca04f074c44b49eb
# ...                                ...
# 8959  d617476c80b6823ed202f5b86916156d
# 8960  d617476c80b6823ed202f5b86916156d
# 8961  d617476c80b6823ed202f5b86916156d
# 8962  d617476c80b6823ed202f5b86916156d
# 8963  d617476c80b6823ed202f5b86916156d
#
# [8964 rows x 1 columns]

# %%
#we collapse data with id of participants
data_id = pd.concat([data,data_id], axis=1).reset_index(drop=True)
data_id
# Out:
#      left_char right_char  strength_left  strength_right  value_left  \
# 0           p2         p6              7               3           8
# 1           p6         p5              3               6           1
# 2           p6         p3              3               8           1
# 3           p7         p6             10               3           0
# 4           p3         p5              8               6           5
# ...        ...        ...            ...             ...         ...
# 8959        p6         p1             11               1           5
# 8960        p5         p2             14              11           7
# 8961        p6         p1             11               1           6
# 8962        p1         p4              1              11           5
# 8963        p5         p7             14              10           5
#
#       scenario  value_left_rep1  value_left_rep2  sex  age  \
# 0            4               -1               -1    0   57
# 1            2               -1               -1    0   57
# 2            3               -1               -1    0   57
# 3            9               -1               -1    0   57
# 4            7               -1               -1    0   57
# ...        ...              ...              ...  ...  ...
# 8959         8                7                8    1   21
# 8960         5                6                7    1   21
# 8961         2                9                5    1   21
# 8962         7                3                2    1   21
# 8963         4                3                5    1   21
#
#                         id_participant
# 0     d60c0832fc30e645ca04f074c44b49eb
# 1     d60c0832fc30e645ca04f074c44b49eb
# 2     d60c0832fc30e645ca04f074c44b49eb
# 3     d60c0832fc30e645ca04f074c44b49eb
# 4     d60c0832fc30e645ca04f074c44b49eb
# ...                                ...
# 8959  d617476c80b6823ed202f5b86916156d
# 8960  d617476c80b6823ed202f5b86916156d
# 8961  d617476c80b6823ed202f5b86916156d
# 8962  d617476c80b6823ed202f5b86916156d
# 8963  d617476c80b6823ed202f5b86916156d
#
# [8964 rows x 11 columns]

# %% [markdown]
# ## Distribution of the perceived force

# %%
plt.rcParams['figure.figsize'] = (30, 9)
character = data_id.left_char.unique()
strength = []
for i in character:
    strength.append(data_id[data_id.left_char == i][[
        "left_char", "strength_left", "id_participant"]].drop_duplicates(subset=['id_participant'])["strength_left"])

plt.boxplot(strength, labels=character)
plt.title("Distribution of the perceived force")
plt.show()

# %% [markdown]
# ## Distribution of pairs

# %%
plt.title("Number of pairs distributed among all scenarios", size=15)
show_pairs_occurence(data, character)
# Out:
# /root/work/library.py:60: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   pairs[(i, j)] = DF[DF.left_char == i][DF.right_char == j].shape[0]
# Mean: 213
# STD: 25.54911236926134
# Max: ('p6', 'p5')  -  246
# Min: ('p3', 'p4')  -  162
# Sum: 4482

# %% [markdown]
# ## Influence of repetitions

# %%
#set figure size
fig, axs = plt.subplots(3, 1, figsize=(20,20))
plt.close(fig)

# %%
#we set the pair observed
l,r = random_pair()
pair_observed = [character[l],character[r]]

#We show for each scenario type
display(Markdown("## For " + pair_observed[0] + " vs " + pair_observed[1]))
display(Markdown("**Influence of repetition in danger scenarios**"))
setup_repetition(axs[0],data[data.scenario < 4], pair_observed, "For " + pair_observed[0] + " vs " + pair_observed[1] + " in Danger")  #danger
display(Markdown("**Influence of repetition in fatigue effort scenarios**"))
setup_repetition(axs[1],data[(data.scenario > 3) & (data.scenario < 7)], pair_observed, "For " + pair_observed[0] + " vs " + pair_observed[1] + " in Fatigue")  #fatigue
display(Markdown("**Influence of repetition in rewards scenarios**"))
setup_repetition(axs[2],data[data.scenario > 6], pair_observed, "For " + pair_observed[0] + " vs " + pair_observed[1] + " in Reward")  #reward
# Out:
# ## For p7 vs p1
# **Influence of repetition in danger scenarios**
# <table><thead><tr><th># of increases</th><th># of decreases</th><th># of constants</th></tr></thead><tbody><tr><td>2</td><td>4</td><td>14</td></tr></tbody></table>
# **Influence of repetition in fatigue effort scenarios**
# <table><thead><tr><th># of increases</th><th># of decreases</th><th># of constants</th></tr></thead><tbody><tr><td>4</td><td>12</td><td>16</td></tr></tbody></table>
# **Influence of repetition in rewards scenarios**
# <table><thead><tr><th># of increases</th><th># of decreases</th><th># of constants</th></tr></thead><tbody><tr><td>3</td><td>7</td><td>17</td></tr></tbody></table>

# %% [markdown]
# ### Plot graphs

# %%
#display graphs
fig.tight_layout()
display(fig)

# %% [markdown]
# # Difference in character's variables

# %%
#set figure size
fig, axs = plt.subplots(3, 2, figsize=(20, 15))
plt.close(fig)

# %% [markdown]
# ## Difference between man and woman

# %%
#dataframe of only pair with man against woman
man = ["p2","p3"]
woman = ["p4","p5"]
data_mw = data[(data.left_char.isin(man)) & (data.right_char.isin(woman))]

# %%
#we print bar plot and anova for this type of pair
title =  "Man vs Woman"
left_label = "Man"
right_label = "Woman"
setup_correlation(axs[0,0], data_mw, man, woman, title, left_label, right_label)
# Out:
# <table><thead><tr><th></th><th>Danger</th><th>Fatigue</th><th>Reward</th></tr></thead><tbody><tr><td>f value</td><td>36.64</td><td>50.53</td><td>0.69</td></tr><tr><td>p value</td><td>2.69e-09</td><td>4.43e-12</td><td>4.06e-01</td></tr></tbody></table>
# **!!! No significant difference in reward scenario !!!**

# %% [markdown]
# ## Difference between robot and human

# %%
#dataframe of only pair with robot against human
robot = ["p7"]
human = [x for x in character if x not in robot]
data_hr = data[(data.left_char.isin(human)) & (data.right_char.isin(robot))]

# %%
#we print bar plot and anova for this type of pair
title =  "Human vs Robot"
left_label = "Human"
right_label = "Robot"
setup_correlation(axs[0,1], data_hr, human, robot, title, left_label, right_label)
# Out:
# <table><thead><tr><th></th><th>Danger</th><th>Fatigue</th><th>Reward</th></tr></thead><tbody><tr><td>f value</td><td>1636.19</td><td>2938.46</td><td>1229.27</td></tr><tr><td>p value</td><td>5.38e-204</td><td>9.76e-301</td><td>4.32e-171</td></tr></tbody></table>

# %% [markdown]
# ## Difference between child, adult and old_person

# %%
#dataframe of only pair with robot against human
child = ["p1"]
old_person = ["p6"]
adult = [x for x in human if (x not in child) and (x not in old_person)]

data_ca = data[(data.left_char.isin(child)) & (data.right_char.isin(adult))]
data_ao = data[(data.left_char.isin(adult)) & (data.right_char.isin(old_person))]
data_co = data[(data.left_char.isin(child)) & (data.right_char.isin(old_person))]

# %%
#we print bar plot and anova for this type of pair
title =  "Child vs Adult"
left_label = "Child"
right_label = "Adult"
setup_correlation(axs[1,0], data_ca, child, adult, title, left_label, right_label)

title =  "Adult vs Old Person"
left_label = "Adult"
right_label = "Old Person"
setup_correlation(axs[1,1], data_ao, adult, old_person, title, left_label, right_label)

title =  "Child vs Old Person"
left_label = "Child"
right_label = "Old Person"
setup_correlation(axs[2,0], data_co, child, old_person, title, left_label, right_label)
# Out:
# <table><thead><tr><th></th><th>Danger</th><th>Fatigue</th><th>Reward</th></tr></thead><tbody><tr><td>f value</td><td>966.04</td><td>2338.12</td><td>241.34</td></tr><tr><td>p value</td><td>4.78e-126</td><td>5.53e-198</td><td>5.51e-45</td></tr></tbody></table>
# <table><thead><tr><th></th><th>Danger</th><th>Fatigue</th><th>Reward</th></tr></thead><tbody><tr><td>f value</td><td>589.2</td><td>1121.73</td><td>72.64</td></tr><tr><td>p value</td><td>2.61e-92</td><td>8.16e-140</td><td>1.51e-16</td></tr></tbody></table>
# <table><thead><tr><th></th><th>Danger</th><th>Fatigue</th><th>Reward</th></tr></thead><tbody><tr><td>f value</td><td>109.79</td><td>41.27</td><td>33.85</td></tr><tr><td>p value</td><td>9.92e-20</td><td>3.33e-09</td><td>4.38e-08</td></tr></tbody></table>

# %% [markdown]
# ## Plot graphs

# %%
#display graphs
fig.delaxes(axs[2,1])
fig.tight_layout()
display(fig)

# %% [markdown]
# # Correlations between force and type of scenarios

# %%
#set figure size
fig, axs = plt.subplots(1, 3, figsize=(26,6))
plt.close(fig)

# %%
#seprate df and put it in array 
danger = data[data.scenario < 4]
fatigue = data[(data.scenario > 3) & (data.scenario < 7)]
reward = data[data.scenario > 6]

#init graph info in dict
graph_info = {"Danger": { "title" : 'Correlation in danger on force perceived',
                        "color" : 'crimson',
                        "type" : "Danger"},
             "Fatigue" : { "title" : 'Correlation in fatigue on force perceived',
                         "color" : 'gold',
                         "type" : "Fatigue"},
             "Reward" : { "title" : 'Correlation in reward on force perceived',
                        "color" : 'turquoise',
                        "type" : "Reward"}
             }

#setup the 3 graphs
setup_force_correlation(axs[0], danger, graph_info["Danger"])
setup_force_correlation(axs[1], fatigue, graph_info["Fatigue"])
setup_force_correlation(axs[2], reward, graph_info["Reward"])
# Out:
# ### Danger
# Spearmans correlation coefficient: 0.469
# Samples are correlated (reject H0) p= 1.50e-163
# ### Fatigue
# Spearmans correlation coefficient: 0.554
# Samples are correlated (reject H0) p= 3.16e-240
# ### Reward
# Spearmans correlation coefficient: -0.053
# Samples are correlated (reject H0) p= 3.71e-03

# %%
#display graphs
fig.tight_layout()
display(fig)

# %% [markdown]
# # Difference in participant's variables

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=df420847-9b7d-4085-bb2b-2d13083511fa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
