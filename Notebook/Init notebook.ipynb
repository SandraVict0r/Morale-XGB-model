# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting git+https://github.com/oracle/Skater.git (from -r ./requirements.txt (line 4))
#   Cloning https://github.com/oracle/Skater.git to /tmp/pip-req-build-sxjr1rfv
#   Resolved https://github.com/oracle/Skater.git to commit f9ad9665e399f4f6687b6d06be1f332abe792f6a
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting statsmodels==0.13.5
#   Downloading statsmodels-0.13.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 130.2 MB/s eta 0:00:00
# Collecting scikit_posthocs==0.7.0
#   Downloading scikit_posthocs-0.7.0-py3-none-any.whl (38 kB)
# Collecting statistics
#   Downloading statistics-1.0.3.5.tar.gz (8.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 1)) (1.21.6)
# Requirement already satisfied: pandas>=0.25 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 1)) (1.2.5)
# Requirement already satisfied: scipy>=1.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 1)) (1.7.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 47.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from statsmodels==0.13.5->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: seaborn in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit_posthocs==0.7.0->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: matplotlib in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit_posthocs==0.7.0->-r ./requirements.txt (line 2)) (3.5.3)
# Collecting docutils>=0.3
#   Downloading docutils-0.19-py3-none-any.whl (570 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.5/570.5 KB 78.9 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.19 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (1.0.2)
# Collecting scikit-image>=0.14
#   Downloading scikit_image-0.19.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 119.2 MB/s eta 0:00:00
# Collecting lime>=0.1.1.21
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 KB 44.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in /shared-libs/python3.7/py/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (2.28.1)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py37-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 KB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: dill>=0.2.6 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (0.3.5.1)
# Requirement already satisfied: joblib>=0.11 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (2.11.3)
# Collecting pydotplus>=2.0.2
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 KB 63.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: plotly>=3.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (5.10.0)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from skater==1.1.2b1->-r ./requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from Jinja2>=2.10.1->skater==1.1.2b1->-r ./requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: tqdm in /shared-libs/python3.7/py/lib/python3.7/site-packages (from lime>=0.1.1.21->skater==1.1.2b1->-r ./requirements.txt (line 4)) (4.64.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging>=21.3->statsmodels==0.13.5->-r ./requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from pandas>=0.25->statsmodels==0.13.5->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas>=0.25->statsmodels==0.13.5->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from plotly>=3.2.0->skater==1.1.2b1->-r ./requirements.txt (line 4)) (8.1.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-image>=0.14->skater==1.1.2b1->-r ./requirements.txt (line 4)) (9.2.0)
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 118.4 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 138.0 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.25.1-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 149.3 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2021.11.2-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 KB 47.7 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from scikit-learn>=0.19->skater==1.1.2b1->-r ./requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from bs4->skater==1.1.2b1->-r ./requirements.txt (line 4)) (4.11.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->scikit_posthocs==0.7.0->-r ./requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->scikit_posthocs==0.7.0->-r ./requirements.txt (line 2)) (4.37.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from matplotlib->scikit_posthocs==0.7.0->-r ./requirements.txt (line 2)) (0.11.0)
# Collecting dill>=0.2.6
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 38.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->skater==1.1.2b1->-r ./requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->skater==1.1.2b1->-r ./requirements.txt (line 4)) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from requests->skater==1.1.2b1->-r ./requirements.txt (line 4)) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from requests->skater==1.1.2b1->-r ./requirements.txt (line 4)) (3.4)
# Requirement already satisfied: typing_extensions in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from seaborn->scikit_posthocs==0.7.0->-r ./requirements.txt (line 2)) (4.4.0)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from beautifulsoup4->bs4->skater==1.1.2b1->-r ./requirements.txt (line 4)) (2.3.2.post1)
# Building wheels for collected packages: statistics, skater, lime, pydotplus, bs4
#   Building wheel for statistics (setup.py): started
#   Building wheel for statistics (setup.py): finished with status 'done'
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7453 sha256=3ff6c772c014a5c29f6e281d96084eaf814d90f6efca5b1925600a12ebb2b64b
#   Stored in directory: /root/.cache/pip/wheels/37/09/e1/49ee45c0ce248a6e9c986aae82d32bbcba09c9f3b9d0c3406a
#   Building wheel for skater (setup.py): started
#   Building wheel for skater (setup.py): finished with status 'done'
#   Created wheel for skater: filename=skater-1.1.2b1-py3-none-any.whl size=119756 sha256=f50d41a97bb5bd2c4ba08ce024439e883468e1a354e8d4f54f9c4885b76f838d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ihu2ekh7/wheels/bc/e1/05/2b5d1c01d1e582236157f04b759d2e140ccc6703f599148c72
#   Building wheel for lime (setup.py): started
#   Building wheel for lime (setup.py): finished with status 'done'
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283845 sha256=ffe69eb4ac34300dfeb8db62830090f2ed9701bbf95162809014aee4aa90ffa4
#   Stored in directory: /root/.cache/pip/wheels/ca/cb/e5/ac701e12d365a08917bf4c6171c0961bc880a8181359c66aa7
#   Building wheel for pydotplus (setup.py): started
#   Building wheel for pydotplus (setup.py): finished with status 'done'
#   Created wheel for pydotplus: filename=pydotplus-2.0.2-py3-none-any.whl size=24568 sha256=c39a366b3fbd8ea15ac6f1db86e767e2b84700357c5d4bda082e38b13b6ff462
#   Stored in directory: /root/.cache/pip/wheels/1e/7b/04/7387cf6cc9e48b4a96e361b0be812f0708b394b821bf8c9c50
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1274 sha256=f9c264ac3cc022dd08d52f0fce2cf19a3727a2abe9341ac228adb60285181372
#   Stored in directory: /root/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built statistics skater lime pydotplus bs4
# Installing collected packages: tifffile, PyWavelets, pydotplus, patsy, networkx, imageio, docutils, dill, statistics, scikit-image, multiprocess, bs4, statsmodels, lime, skater, scikit_posthocs
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Not uninstalling dill at /shared-libs/python3.7/py/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'dill'. No files were found to uninstall.
# Successfully installed PyWavelets-1.3.0 bs4-0.0.1 dill-0.3.6 docutils-0.19 imageio-2.25.1 lime-0.2.0.1 multiprocess-0.70.14 networkx-2.6.3 patsy-0.5.3 pydotplus-2.0.2 scikit-image-0.19.3 scikit_posthocs-0.7.0 skater-1.1.2b1 statistics-1.0.3.5 statsmodels-0.13.5 tifffile-2021.11.2
#   Running command git clone --filter=blob:none --quiet https://github.com/oracle/Skater.git /tmp/pip-req-build-sxjr1rfv
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=df420847-9b7d-4085-bb2b-2d13083511fa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
